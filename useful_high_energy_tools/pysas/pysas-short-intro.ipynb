# %% [markdown]
# # pySAS Short Introduction
#
# ## Learning Goals
#
# By the end of this tutorial, we will demonstrate:
#
# - How to select a directory for data and analysis.
# - How to copy XMM data from the HEASARC archive.
# - How to run the standard XMM SAS commands `cifbuild` and `odfingest` using pySAS.
#
# ## Introduction
#
# This tutorial provides a short, basic introduction to using pySAS. It only covers how to download observation
# data files and how to calibrate the data.
#
# This tutorial is intended for those who are already familiar with SAS commands and want to use them in Python rather than the command line.
#
# ### Inputs
#
# - The XMM ObsID, 0802710101, of the data we will process (an observation of NGC 3079).
#
# ### Outputs
#
#
# ### Runtime
#
# As of {Date}, this notebook takes ~{N}s to run to completion on Fornax using the ‘Default Astrophysics' image and the ‘{name: size}’ server with NGB RAM/ NCPU.
#
# ## Imports

# %%
import os

import pysas
from pysas.sastask import MyTask
# Out:
# There is a problem with SAS_DIR in the config file!
# /does/not/exist does not exist!
# Please set manually to initialize SAS.
# There is a problem with SAS_CCFPATH in the config file!
# /does/not/exist does not exist!
# Please set manually to initialize SAS.

# %%
pysas.__version__
# Out:
# 'pysas - (pysas-2.2.7) [SAS-22.1.0-a8f2c2afa-20250304]'

# %% [markdown]
# ## Global Setup
#
# ### Functions

# %%
# This cell will be automatically collapsed when the notebook is rendered, which helps
#  to hide large and distracting functions while keeping the notebook self-contained
#  and leaving them easily accessible to the user

# %% [markdown]
# ### Constants

# %%
OBS_ID = "0802710101"

# %% [markdown]
# ### Configuration
#
# The only configuration we do is to set up the root directory where we will store downloaded data.

# %%
if os.path.exists("../../../_data"):
    ROOT_DATA_DIR = os.path.join(os.path.abspath("../../../_data"), "XMM", "")
else:
    ROOT_DATA_DIR = "XMM/"

os.makedirs(ROOT_DATA_DIR, exist_ok=True)

# %% [markdown]
# ***
#
# ## 1. Download observation data files (ODF) and run setup tasks
#
# When you run the cell below, the following things will happen.
#
# 1. `basic_setup` will check if `data_dir` exists, and if not it will create it.
# 2. Inside data_dir `basic_setup` will create a directory with the value for the ObsID (i.e. `$data_dir/0802710101/`).
# 3. Within the ObsID directory, `basic_setup` will create two directories:
#
#     a. `$data_dir/0802710101/ODF` where the observation data files are kept.
#
#     b. `$data_dir/0802710101/work` where the `ccf.cif`, `*SUM.SAS`, and output files are kept.
# 4. `basic_setup` will automatically transfer the data for `obsid` to `$data_dir/0802710101/ODF` from the HEASARC archive.
# 5. `basic_setup` will run `cifbuild` and `odfingest`.
# 6. `basic_setup` will then run the basic pipeline tasks `emproc`, `epproc`, and `rgsproc`. The output of these three tasks will be in the `work_dir`.
#
# That is it! Your data is now calibrated, processed, and ready for use with all the standard SAS commands!

# %%
obs = pysas.ObsID(OBS_ID, ROOT_DATA_DIR)
obs.basic_setup(repo="heasarc", overwrite=False, level="ODF")
# Out:
#         Starting SAS session
#
#         Data directory = /home/jovyan/projects/heasarc-tutorials/_data/XMM/
#
#
# INFO: Downloading data from the HEASARC ... [astroquery.heasarc.core]
# INFO: Downloading to /home/jovyan/projects/heasarc-tutorials/_data/XMM//heasarc-data.tar ... [astroquery.heasarc.core]
# INFO: Untar /home/jovyan/projects/heasarc-tutorials/_data/XMM//heasarc-data.tar to /home/jovyan/projects/heasarc-tutorials/_data/XMM/ ... [astroquery.heasarc.core]
# Data directory: /home/jovyan/projects/heasarc-tutorials/_data/XMM/
#
# Setting SAS_ODF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF
#
# Running cifbuild with inputs: {} ...
# Executing:
# cifbuild calindexset='ccf.cif' withccfpath='no' ccfpath='.' usecanonicalname='no' recurse='no' fileglob='*.ccf|*.CCF' fullpath='no' withobservationdate='no' observationdate='now' analysisdate='now' category='XMMCCF' ignorecategory='no' masterindex='no' withmasterindexset='no' masterindexset='ccf.mif' append='no'
# cifbuild:- Executing (routine): cifbuild calindexset=ccf.cif ccfpath=. withccfpath=no usecanonicalname=no recurse=no fileglob=*.ccf|*.CCF fullpath=no observationdate=now withobservationdate=no analysisdate=now category=XMMCCF ignorecategory=no masterindex=no masterindexset=ccf.mif withmasterindexset=no append=no  -w 1 -V 4
# cifbuild:- cifbuild (cifbuild-4.10.1)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T17:57:41.000
# cifbuild:- Will ask the analysis date to the OAL.
# cifbuild:- Using the ODF 3278_0802710101 found in /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF
# cifbuild:- Observation date: 2017-11-01T10:42:37.000
# cifbuild:- Analysis date: 2026-01-09T17:57:41.000
# cifbuild:- cifbuild (cifbuild-4.10.1)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T17:59:15.000
# cifbuild executed successfully!
#
# Setting SAS_CCF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/ccf.cif
#
# Running odfingest with inputs: {} ...
# Executing:
# odfingest odfdir='.' withodfdir='no' outdir='.' summaryfile='0000_0000000000_SCX000SUM.SAS' usecanonicalname='yes' writepath='yes' findinstrumentmodes='yes' usehousekeeping='yes' oalcheck='no'
# odfingest:- Executing (routine): odfingest odfdir=. withodfdir=no outdir=. summaryfile=0000_0000000000_SCX000SUM.SAS usecanonicalname=yes writepath=yes findinstrumentmodes=yes usehousekeeping=yes oalcheck=no  -w 1 -V 4
# odfingest:- odfingest (odfingest-3.33.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T17:59:16.000
# odfingest:- Looking for ODF constituents in /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/
# odfingest:- Identified the following ODF
# Revolution:  3278
# Observation: 0802710101
# Proposal:    0802710101
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00100AUX.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00110IME.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00120IME.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00140IME.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00150IME.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M1S00170IME.FIT : 2017-11-01T11:00:11.000 - 2017-11-01T16:57:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00200AUX.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00210IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00220IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00230IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00240IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00250IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00260IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_M2S00270IME.FIT : 2017-11-01T11:00:44.000 - 2017-11-01T16:57:52.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00600IMI.FIT : 2017-11-01T11:06:35.000 - 2017-11-01T12:25:05.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00600PFX.FIT : 2017-11-01T11:06:35.000 - 2017-11-01T12:25:05.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00600RFX.FIT : 2017-11-01T11:06:35.000 - 2017-11-01T12:25:05.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00600WDX.FIT : 2017-11-01T11:06:35.000 - 2017-11-01T12:25:05.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00601FAE.FIT : 2017-11-01T11:06:35.000 - 2017-11-01T12:25:05.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00700IMI.FIT : 2017-11-01T12:25:05.000 - 2017-11-01T13:43:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00700PFX.FIT : 2017-11-01T12:25:05.000 - 2017-11-01T13:43:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00700RFX.FIT : 2017-11-01T12:25:05.000 - 2017-11-01T13:43:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00700WDX.FIT : 2017-11-01T12:25:05.000 - 2017-11-01T13:43:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00701FAE.FIT : 2017-11-01T12:25:05.000 - 2017-11-01T13:43:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00800IMI.FIT : 2017-11-01T13:43:35.000 - 2017-11-01T15:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00800PFX.FIT : 2017-11-01T13:43:35.000 - 2017-11-01T15:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00800RFX.FIT : 2017-11-01T13:43:35.000 - 2017-11-01T15:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00800WDX.FIT : 2017-11-01T13:43:35.000 - 2017-11-01T15:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00801FAE.FIT : 2017-11-01T13:43:35.000 - 2017-11-01T15:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00900IMI.FIT : 2017-11-01T15:01:56.000 - 2017-11-01T16:20:25.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00900PFX.FIT : 2017-11-01T15:01:56.000 - 2017-11-01T16:20:25.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00900RFX.FIT : 2017-11-01T15:01:56.000 - 2017-11-01T16:20:25.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00900WDX.FIT : 2017-11-01T15:01:56.000 - 2017-11-01T16:20:25.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS00901FAE.FIT : 2017-11-01T15:01:56.000 - 2017-11-01T16:20:25.000
# odfingest:- DATE-END = 2017-11-01T17:08:28 as reported by 3278_0802710101_OMS01000IMI.FIT is later than the last available housekeeping record 2017-11-01T17:02:37 I'll set DATE-END to match the date reported by the housekeeping.
# odfingest:- Dataset Time Range: 3278_0802710101_OMS01000IMI.FIT : 2017-11-01T16:20:25.000 - 2017-11-01T17:02:37.000
# odfingest:- DATE-END = 2017-11-01T17:08:28 as reported by 3278_0802710101_OMS01000PFX.FIT is later than the last available housekeeping record 2017-11-01T17:02:37 I'll set DATE-END to match the date reported by the housekeeping.
# odfingest:- Dataset Time Range: 3278_0802710101_OMS01000PFX.FIT : 2017-11-01T16:20:25.000 - 2017-11-01T17:02:37.000
# odfingest:- DATE-END = 2017-11-01T17:08:28 as reported by 3278_0802710101_OMS01000RFX.FIT is later than the last available housekeeping record 2017-11-01T17:02:37 I'll set DATE-END to match the date reported by the housekeeping.
# odfingest:- Dataset Time Range: 3278_0802710101_OMS01000RFX.FIT : 2017-11-01T16:20:25.000 - 2017-11-01T17:02:37.000
# odfingest:- DATE-END = 2017-11-01T17:08:28 as reported by 3278_0802710101_OMS01000WDX.FIT is later than the last available housekeeping record 2017-11-01T17:02:37 I'll set DATE-END to match the date reported by the housekeeping.
# odfingest:- Dataset Time Range: 3278_0802710101_OMS01000WDX.FIT : 2017-11-01T16:20:25.000 - 2017-11-01T17:02:37.000
# odfingest:- DATE-END = 2017-11-01T17:08:28 as reported by 3278_0802710101_OMS01001FAE.FIT is later than the last available housekeeping record 2017-11-01T17:02:37 I'll set DATE-END to match the date reported by the housekeeping.
# odfingest:- Dataset Time Range: 3278_0802710101_OMS01001FAE.FIT : 2017-11-01T16:20:25.000 - 2017-11-01T17:02:37.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS40000PAX.FIT : 2017-11-01T11:02:33.000 - 2017-11-01T11:06:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_OMS40000RFX.FIT : 2017-11-01T11:02:33.000 - 2017-11-01T11:06:35.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00300AUX.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00301IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00302IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00303IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00304IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00305IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00306IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00307IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00308IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00309IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00310IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00311IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNS00312IME.FIT : 2017-11-01T11:23:00.000 - 2017-11-01T16:53:41.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00400AUX.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00401SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00402SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00403SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00404SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00405SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00406SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00408SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_R1S00409SPE.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T17:01:56.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90001DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90102DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90203DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90304DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90405DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90506DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90608DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90709DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90801DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S90902DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S91003DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S91104DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S91205DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S91306DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R1S91408DII.FIT : 2017-11-01T11:00:02.000 - 2017-11-01T11:00:03.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00500AUX.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00501SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00502SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00503SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00505SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00506SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00507SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00508SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Dataset Time Range: 3278_0802710101_R2S00509SPE.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T17:01:58.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90001DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90102DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90203DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90305DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90406DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90507DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90608DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90709DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90801DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S90902DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S91003DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S91105DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S91206DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S91307DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_R2S91408DII.FIT : 2017-11-01T11:00:10.000 - 2017-11-01T11:00:11.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00201DLI.FIT : 2017-11-01T16:57:11.000 - 2017-11-01T16:57:12.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00302DLI.FIT : 2017-11-01T16:57:33.000 - 2017-11-01T16:57:34.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00403DLI.FIT : 2017-11-01T16:57:52.000 - 2017-11-01T16:57:53.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00504DLI.FIT : 2017-11-01T16:58:16.000 - 2017-11-01T16:58:17.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00605DLI.FIT : 2017-11-01T16:58:38.000 - 2017-11-01T16:58:39.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00706DLI.FIT : 2017-11-01T16:58:56.000 - 2017-11-01T16:58:57.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00807DLI.FIT : 2017-11-01T16:59:21.000 - 2017-11-01T16:59:22.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU00908DLI.FIT : 2017-11-01T16:59:43.000 - 2017-11-01T16:59:44.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU01009DLI.FIT : 2017-11-01T17:00:01.000 - 2017-11-01T17:00:02.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU01110DLI.FIT : 2017-11-01T17:00:25.000 - 2017-11-01T17:00:26.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU01211DLI.FIT : 2017-11-01T17:00:48.000 - 2017-11-01T17:00:49.000
# odfingest:- Detected a data set with data mode 19 [DiscardedLinesData]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3278_0802710101_PNU01312DLI.FIT : 2017-11-01T17:01:06.000 - 2017-11-01T17:01:07.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10101ODI.FIT : 2017-11-01T11:14:32.000 - 2017-11-01T11:14:57.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10102ODI.FIT : 2017-11-01T11:15:11.000 - 2017-11-01T11:15:38.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10103ODI.FIT : 2017-11-01T11:15:50.000 - 2017-11-01T11:16:16.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10104ODI.FIT : 2017-11-01T11:16:41.000 - 2017-11-01T11:17:07.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10105ODI.FIT : 2017-11-01T11:17:21.000 - 2017-11-01T11:17:47.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10106ODI.FIT : 2017-11-01T11:18:00.000 - 2017-11-01T11:18:27.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10107ODI.FIT : 2017-11-01T11:18:51.000 - 2017-11-01T11:19:17.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10108ODI.FIT : 2017-11-01T11:19:31.000 - 2017-11-01T11:19:56.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10109ODI.FIT : 2017-11-01T11:20:11.000 - 2017-11-01T11:20:37.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10110ODI.FIT : 2017-11-01T11:21:01.000 - 2017-11-01T11:21:27.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10111ODI.FIT : 2017-11-01T11:21:41.000 - 2017-11-01T11:22:06.000
# odfingest:- Dataset Time Range: 3278_0802710101_PNU10112ODI.FIT : 2017-11-01T11:22:21.000 - 2017-11-01T11:22:47.000
# odfingest:- Observation Time Range: 2017-11-01T11:00:02.000 - 2017-11-01T17:02:37.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S900 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S901 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S902 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S903 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S904 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S905 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S906 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S907 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S908 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S909 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S910 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S911 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S912 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S913 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S914 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S900 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S901 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S902 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S903 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S904 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S905 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S906 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S907 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S908 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S909 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S910 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S911 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S912 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S913 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S914 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/U002 start = 2017-11-01T16:57:11.000 end = 2017-11-01T16:57:12.000
# odfingest:- PN/U003 start = 2017-11-01T16:57:33.000 end = 2017-11-01T16:57:34.000
# odfingest:- PN/U004 start = 2017-11-01T16:57:52.000 end = 2017-11-01T16:57:53.000
# odfingest:- PN/U005 start = 2017-11-01T16:58:16.000 end = 2017-11-01T16:58:17.000
# odfingest:- PN/U006 start = 2017-11-01T16:58:38.000 end = 2017-11-01T16:58:39.000
# odfingest:- PN/U007 start = 2017-11-01T16:58:56.000 end = 2017-11-01T16:58:57.000
# odfingest:- PN/U008 start = 2017-11-01T16:59:21.000 end = 2017-11-01T16:59:22.000
# odfingest:- PN/U009 start = 2017-11-01T16:59:43.000 end = 2017-11-01T16:59:44.000
# odfingest:- PN/U010 start = 2017-11-01T17:00:01.000 end = 2017-11-01T17:00:02.000
# odfingest:- PN/U011 start = 2017-11-01T17:00:25.000 end = 2017-11-01T17:00:26.000
# odfingest:- PN/U012 start = 2017-11-01T17:00:48.000 end = 2017-11-01T17:00:49.000
# odfingest:- PN/U013 start = 2017-11-01T17:01:06.000 end = 2017-11-01T17:01:07.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S400 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S400 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M1/S001 start = 2017-11-01T11:00:11.000 end = 2017-11-01T16:57:47.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- M2/S002 start = 2017-11-01T11:00:44.000 end = 2017-11-01T16:57:52.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S004 start = 2017-11-01T11:00:02.000 end = 2017-11-01T17:01:56.000
# odfingest:- R1/S900 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S900 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S901 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S901 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S902 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S902 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S903 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S903 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S904 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S904 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S905 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S905 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S906 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S906 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S907 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S907 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S908 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S908 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S909 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S909 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S910 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S910 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S911 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S911 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S912 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S912 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S913 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S913 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S914 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R1/S914 start = 2017-11-01T11:00:02.000 end = 2017-11-01T11:00:03.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S005 start = 2017-11-01T11:00:10.000 end = 2017-11-01T17:01:58.000
# odfingest:- R2/S900 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S900 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S901 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S901 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S902 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S902 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S903 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S903 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S904 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S904 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S905 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S905 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S906 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S906 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S907 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S907 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S908 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S908 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S909 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S909 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S910 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S910 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S911 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S911 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S912 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S912 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S913 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S913 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S914 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- R2/S914 start = 2017-11-01T11:00:10.000 end = 2017-11-01T11:00:11.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- PN/S003 start = 2017-11-01T11:23:00.000 end = 2017-11-01T16:53:41.000
# odfingest:- Summary of the FILTER information for INSTEXP PN/S003 F1120 [ Medium ] Potentiometer val [ 233.234 ] F1118 [ FILTC-MEDIUM ] FD130 [ MEDIUM ]
# odfingest:- PN/U002 start = 2017-11-01T16:57:11.000 end = 2017-11-01T16:57:12.000
# odfingest:- PN/U002 start = 2017-11-01T16:57:11.000 end = 2017-11-01T16:57:12.000
# odfingest:- Possible matches for PN filter: 0
# ** odfingest: warning (TranslationNotAvailable), No look up possible [EPN Filter]It is not possible to translate FILTER. Its raw value is -nan
# ** odfingest: warning (HousekeepingParameterMissing), PN/U002 NoAvailableRows: No rows match the expression (F1119 == "STOPPED") && (#ROW >= 2886 && #ROW <= 2885) in /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_PNX00000PMH.FIT:PNPMH1
# odfingest:- PN/U003 start = 2017-11-01T16:57:33.000 end = 2017-11-01T16:57:34.000
# odfingest:- PN/U003 start = 2017-11-01T16:57:33.000 end = 2017-11-01T16:57:34.000
# odfingest:- PN/U004 start = 2017-11-01T16:57:52.000 end = 2017-11-01T16:57:53.000
# odfingest:- PN/U004 start = 2017-11-01T16:57:52.000 end = 2017-11-01T16:57:53.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U005 start = 2017-11-01T16:58:16.000 end = 2017-11-01T16:58:17.000
# odfingest:- PN/U005 start = 2017-11-01T16:58:16.000 end = 2017-11-01T16:58:17.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U006 start = 2017-11-01T16:58:38.000 end = 2017-11-01T16:58:39.000
# odfingest:- PN/U006 start = 2017-11-01T16:58:38.000 end = 2017-11-01T16:58:39.000
# odfingest:- PN/U007 start = 2017-11-01T16:58:56.000 end = 2017-11-01T16:58:57.000
# odfingest:- PN/U007 start = 2017-11-01T16:58:56.000 end = 2017-11-01T16:58:57.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U008 start = 2017-11-01T16:59:21.000 end = 2017-11-01T16:59:22.000
# odfingest:- PN/U008 start = 2017-11-01T16:59:21.000 end = 2017-11-01T16:59:22.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U009 start = 2017-11-01T16:59:43.000 end = 2017-11-01T16:59:44.000
# odfingest:- PN/U009 start = 2017-11-01T16:59:43.000 end = 2017-11-01T16:59:44.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U010 start = 2017-11-01T17:00:01.000 end = 2017-11-01T17:00:02.000
# odfingest:- PN/U010 start = 2017-11-01T17:00:01.000 end = 2017-11-01T17:00:02.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U011 start = 2017-11-01T17:00:25.000 end = 2017-11-01T17:00:26.000
# odfingest:- PN/U011 start = 2017-11-01T17:00:25.000 end = 2017-11-01T17:00:26.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U012 start = 2017-11-01T17:00:48.000 end = 2017-11-01T17:00:49.000
# odfingest:- PN/U012 start = 2017-11-01T17:00:48.000 end = 2017-11-01T17:00:49.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U013 start = 2017-11-01T17:01:06.000 end = 2017-11-01T17:01:07.000
# odfingest:- PN/U013 start = 2017-11-01T17:01:06.000 end = 2017-11-01T17:01:07.000
# odfingest:- Possible matches for PN filter: 0
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- PN/U101 start = 2017-11-01T11:14:32.000 end = 2017-11-01T11:22:47.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S006 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S007 start = 2017-11-01T12:27:33.000 end = 2017-11-01T13:40:54.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S008 start = 2017-11-01T13:46:00.000 end = 2017-11-01T14:59:20.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S009 start = 2017-11-01T15:04:28.000 end = 2017-11-01T16:17:47.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S010 start = 2017-11-01T16:22:54.000 end = 2017-11-01T17:00:54.000
# odfingest:- OM/S400 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- OM/S400 start = 2017-11-01T11:09:06.000 end = 2017-11-01T12:22:26.000
# odfingest:- odfingest (odfingest-3.33.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T17:59:28.000
# ** odfingest: warning (SummaryOfWarnings),
# warning HousekeepingParameterMissing silently occurred 19 times
# warning TranslationNotAvailable silently occurred 9 times
#
# Setting SAS_ODF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/3278_0802710101_SCX00000SUM.SAS
# odfingest executed successfully!
#
# Summary file PATH keyword matches /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF
#
#
#
#         SAS_CCF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/ccf.cif
#         SAS_ODF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/3278_0802710101_SCX00000SUM.SAS
#
#
# SAS_ODF = /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/3278_0802710101_SCX00000SUM.SAS
#    SAS command to be executed: epproc, with arguments; {}
# Running epproc .....
#
# Executing:
# ...
# rgsproc::rgslccorr:- Source: CCD 3 Counts= 54 Area= 0.001671084021756024697
# rgsproc::rgslccorr:- Background: CCD 3 Counts= 63 Area= 0.0027600480359333658467
# rgsproc::rgslccorr:- Selecting events from CCDNR==4
# rgsproc::rgslccorr:- selected 41 rows from source file CCDNR==4
# rgsproc::rgslccorr:- selected 61 rows from background file CCDNR==4
# rgsproc::rgslccorr:- Calculating source area for CCDNR==4
# rgsproc::rgslccorr:- Calculating background area for CCDNR==4
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==4...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==4...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 4 Counts= 41 Area= 0.0015905160207071011164
# rgsproc::rgslccorr:- Background: CCD 4 Counts= 61 Area= 0.0024939360324688244867
# rgsproc::rgslccorr:- Selecting events from CCDNR==5
# rgsproc::rgslccorr:- selected 53 rows from source file CCDNR==5
# rgsproc::rgslccorr:- selected 42 rows from background file CCDNR==5
# rgsproc::rgslccorr:- Calculating source area for CCDNR==5
# rgsproc::rgslccorr:- Calculating background area for CCDNR==5
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==5...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==5...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 5 Counts= 53 Area= 0.00156405602036261554
# rgsproc::rgslccorr:- Background: CCD 5 Counts= 42 Area= 0.0022555800293656419475
# rgsproc::rgslccorr:- Selecting events from CCDNR==6
# rgsproc::rgslccorr:- selected 39 rows from source file CCDNR==6
# rgsproc::rgslccorr:- selected 44 rows from background file CCDNR==6
# rgsproc::rgslccorr:- Calculating source area for CCDNR==6
# rgsproc::rgslccorr:- Calculating background area for CCDNR==6
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==6...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==6...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 6 Counts= 39 Area= 0.0015488280201643605562
# rgsproc::rgslccorr:- Background: CCD 6 Counts= 44 Area= 0.0019643040255734878219
# rgsproc::rgslccorr:- Selecting events from CCDNR==7
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==7
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==7
# rgsproc::rgslccorr:- Calculating source area for CCDNR==7
# rgsproc::rgslccorr:- Calculating background area for CCDNR==7
# rgsproc::rgslccorr:- Selecting events from CCDNR==8
# rgsproc::rgslccorr:- selected 68 rows from source file CCDNR==8
# rgsproc::rgslccorr:- selected 60 rows from background file CCDNR==8
# rgsproc::rgslccorr:- Calculating source area for CCDNR==8
# rgsproc::rgslccorr:- Calculating background area for CCDNR==8
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==8...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==8...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 8 Counts= 68 Area= 0.0014152320184250596468
# rgsproc::rgslccorr:- Background: CCD 8 Counts= 60 Area= 0.0015029280195667834696
# rgsproc::rgslccorr:- Selecting events from CCDNR==9
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==9
# rgsproc::rgslccorr:- selected 1 rows from background file CCDNR==9
# rgsproc::rgslccorr:- Calculating source area for CCDNR==9
# rgsproc::rgslccorr:- Calculating background area for CCDNR==9
# rgsproc::rgslccorr:- Adding source lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Adding background lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Next CCD: Src counts 51 Src Area 0.0017502480227866695078
# rgsproc::rgslccorr:- Next CCD: Src counts 51 Src Area 0.0017422560226826207253
# rgsproc::rgslccorr:- Next CCD: Src counts 54 Src Area 0.001671084021756024697
# rgsproc::rgslccorr:- Next CCD: Src counts 41 Src Area 0.0015905160207071011164
# rgsproc::rgslccorr:- Next CCD: Src counts 53 Src Area 0.00156405602036261554
# rgsproc::rgslccorr:- Next CCD: Src counts 39 Src Area 0.0015488280201643605562
# rgsproc::rgslccorr:- Next CCD: Src counts 68 Src Area 0.0014152320184250596468
# rgsproc::rgslccorr:- Next CCD Bkg counts 77 Bkg Area 0.0032016600416827608114
# rgsproc::rgslccorr:- Next CCD Bkg counts 119 Bkg Area 0.003053808039757859201
# rgsproc::rgslccorr:- Next CCD Bkg counts 63 Bkg Area 0.0027600480359333658467
# rgsproc::rgslccorr:- Next CCD Bkg counts 61 Bkg Area 0.0024939360324688244867
# rgsproc::rgslccorr:- Next CCD Bkg counts 42 Bkg Area 0.0022555800293656419475
# rgsproc::rgslccorr:- Next CCD Bkg counts 44 Bkg Area 0.0019643040255734878219
# rgsproc::rgslccorr:- Next CCD Bkg counts 60 Bkg Area 0.0015029280195667834696
# rgsproc::rgslccorr:- Mean BACKSCALE 0.68342132104074360122
# rgsproc::rgslccorr:- subtracting background lightcurve...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Creating output file...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Deleting temporary files and cleaning memory...
# rgsproc::rgslccorr:- done.
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:36.000
# rgsproc:- Executing (routine): rgslccorr evlist=P0802710101R2S005EVENLI0000.FIT srclist=P0802710101R2S005SRCLI_0000.FIT timebinsize=1000 timemin=0 timemax=1000 withtimeranges=no orders=2 sourceid=1 outputsrcfilename=P0802710101R2S005SRTSR_2001.FIT outputbkgfilename=P0802710101R2S005BGTSR_2001.FIT withbkgsubtraction=yes withfiltering=no lambdamin=0 lambdamax=0 energymin=0 energymax=0 filtering=wavelength withccdselection=no ccds=1  -w 1 -V 4
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:36.000
# rgsproc::rgslccorr:- Source expression used: REGION(P0802710101R2S005SRCLI_0000.FIT:RGS2_SRC1_SPATIAL,M_LAMBDA,XDSP_CORR) && ( REGION(P0802710101R2S005SRCLI_0000.FIT:RGS2_SRC1_ORDER_2,M_LAMBDA,PI)  )
# rgsproc::rgslccorr:- selected 391 rows from the source input table.
# rgsproc::rgslccorr:- Background expression REGION(P0802710101R2S005SRCLI_0000.FIT:RGS2_BACKGROUND,M_LAMBDA,XDSP_CORR) && ( REGION(P0802710101R2S005SRCLI_0000.FIT:RGS2_SRC1_ORDER_2,M_LAMBDA,PI)  )
# rgsproc::rgslccorr:- selected 541 rows from the background input table.
# rgsproc::rgslccorr:- Time start selected 625921366.92900300026
# rgsproc::rgslccorr:- Time stop selected  625942973.93190956116
# rgsproc::rgslccorr:- Selecting events from CCDNR==1
# rgsproc::rgslccorr:- selected 49 rows from source file CCDNR==1
# rgsproc::rgslccorr:- selected 90 rows from background file CCDNR==1
# rgsproc::rgslccorr:- Calculating source area for CCDNR==1
# rgsproc::rgslccorr:- Calculating background area for CCDNR==1
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==1...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==1...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 1 Counts= 49 Area= 0.0019217520250194987212
# rgsproc::rgslccorr:- Background: CCD 1 Counts= 90 Area= 0.0028032480364957911359
# rgsproc::rgslccorr:- Selecting events from CCDNR==2
# rgsproc::rgslccorr:- selected 62 rows from source file CCDNR==2
# rgsproc::rgslccorr:- selected 94 rows from background file CCDNR==2
# rgsproc::rgslccorr:- Calculating source area for CCDNR==2
# rgsproc::rgslccorr:- Calculating background area for CCDNR==2
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==2...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==2...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 2 Counts= 62 Area= 0.0019348200251896325707
# rgsproc::rgslccorr:- Background: CCD 2 Counts= 94 Area= 0.0028351080369105803071
# rgsproc::rgslccorr:- Selecting events from CCDNR==3
# rgsproc::rgslccorr:- selected 74 rows from source file CCDNR==3
# rgsproc::rgslccorr:- selected 58 rows from background file CCDNR==3
# rgsproc::rgslccorr:- Calculating source area for CCDNR==3
# rgsproc::rgslccorr:- Calculating background area for CCDNR==3
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==3...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==3...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 3 Counts= 74 Area= 0.0018416160239761994108
# rgsproc::rgslccorr:- Background: CCD 3 Counts= 58 Area= 0.002655288034569484
# rgsproc::rgslccorr:- Selecting events from CCDNR==4
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==4
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==4
# rgsproc::rgslccorr:- Calculating source area for CCDNR==4
# rgsproc::rgslccorr:- Calculating background area for CCDNR==4
# rgsproc::rgslccorr:- Selecting events from CCDNR==5
# rgsproc::rgslccorr:- selected 43 rows from source file CCDNR==5
# rgsproc::rgslccorr:- selected 62 rows from background file CCDNR==5
# rgsproc::rgslccorr:- Calculating source area for CCDNR==5
# rgsproc::rgslccorr:- Calculating background area for CCDNR==5
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==5...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==5...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 5 Counts= 43 Area= 0.0014817600192911950952
# rgsproc::rgslccorr:- Background: CCD 5 Counts= 62 Area= 0.0021485520279722327905
# rgsproc::rgslccorr:- Selecting events from CCDNR==6
# rgsproc::rgslccorr:- selected 44 rows from source file CCDNR==6
# rgsproc::rgslccorr:- selected 53 rows from background file CCDNR==6
# rgsproc::rgslccorr:- Calculating source area for CCDNR==6
# rgsproc::rgslccorr:- Calculating background area for CCDNR==6
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==6...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==6...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 6 Counts= 44 Area= 0.0014040000182788290543
# rgsproc::rgslccorr:- Background: CCD 6 Counts= 53 Area= 0.0020014560260571737614
# rgsproc::rgslccorr:- Selecting events from CCDNR==7
# rgsproc::rgslccorr:- selected 95 rows from source file CCDNR==7
# rgsproc::rgslccorr:- selected 148 rows from background file CCDNR==7
# rgsproc::rgslccorr:- Calculating source area for CCDNR==7
# rgsproc::rgslccorr:- Calculating background area for CCDNR==7
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==7...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==7...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 7 Counts= 95 Area= 0.0012960000168727653976
# rgsproc::rgslccorr:- Background: CCD 7 Counts= 148 Area= 0.0018700200243459942032
# rgsproc::rgslccorr:- Selecting events from CCDNR==8
# rgsproc::rgslccorr:- selected 24 rows from source file CCDNR==8
# rgsproc::rgslccorr:- selected 36 rows from background file CCDNR==8
# rgsproc::rgslccorr:- Calculating source area for CCDNR==8
# rgsproc::rgslccorr:- Calculating background area for CCDNR==8
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==8...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==8...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 8 Counts= 24 Area= 0.0011689920152192342841
# rgsproc::rgslccorr:- Background: CCD 8 Counts= 36 Area= 0.0016911720220175526126
# rgsproc::rgslccorr:- Selecting events from CCDNR==9
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==9
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==9
# rgsproc::rgslccorr:- Calculating source area for CCDNR==9
# rgsproc::rgslccorr:- Calculating background area for CCDNR==9
# rgsproc::rgslccorr:- Adding source lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Adding background lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Next CCD: Src counts 49 Src Area 0.0019217520250194987212
# rgsproc::rgslccorr:- Next CCD: Src counts 62 Src Area 0.0019348200251896325707
# rgsproc::rgslccorr:- Next CCD: Src counts 74 Src Area 0.0018416160239761994108
# rgsproc::rgslccorr:- Next CCD: Src counts 43 Src Area 0.0014817600192911950952
# rgsproc::rgslccorr:- Next CCD: Src counts 44 Src Area 0.0014040000182788290543
# rgsproc::rgslccorr:- Next CCD: Src counts 95 Src Area 0.0012960000168727653976
# rgsproc::rgslccorr:- Next CCD: Src counts 24 Src Area 0.0011689920152192342841
# rgsproc::rgslccorr:- Next CCD Bkg counts 90 Bkg Area 0.0028032480364957911359
# rgsproc::rgslccorr:- Next CCD Bkg counts 94 Bkg Area 0.0028351080369105803071
# rgsproc::rgslccorr:- Next CCD Bkg counts 58 Bkg Area 0.002655288034569484
# rgsproc::rgslccorr:- Next CCD Bkg counts 62 Bkg Area 0.0021485520279722327905
# rgsproc::rgslccorr:- Next CCD Bkg counts 53 Bkg Area 0.0020014560260571737614
# rgsproc::rgslccorr:- Next CCD Bkg counts 148 Bkg Area 0.0018700200243459942032
# rgsproc::rgslccorr:- Next CCD Bkg counts 36 Bkg Area 0.0016911720220175526126
# rgsproc::rgslccorr:- Mean BACKSCALE 0.69099678399363972936
# rgsproc::rgslccorr:- subtracting background lightcurve...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Creating output file...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Deleting temporary files and cleaning memory...
# rgsproc::rgslccorr:- done.
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:39.000
# rgsproc:- rgsproc (rgsproc-1.39)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:39.000
# ** rgsproc: warning (SummaryOfWarnings),
# warning ArgumentIgnored silently occurred 47 times
# warning BadPixDiscrepancy silently occurred 30 times
# warning InvalidCoordinates silently occurred 11 times
# warning NoFilteredEvents silently occurred 5 times
# warning badPrimeRate silently occurred 1 times
# warning binning  silently occurred 5072 times
# warning outside range silently occurred 5072 times
# rgsproc executed successfully!

# %% [markdown]
# If you want more information on the function `basic_setup` run the cell below or see the long introduction tutorial.

# %%
obs.basic_setup?
# Out:
# Signature:
# obs.basic_setup(
#     data_dir=None,
#     repo=None,
#     overwrite=False,
#     rerun=False,
#     recalibrate=False,
#     run_epproc=True,
#     run_emproc=True,
#     run_rgsproc=True,
#     run_epchain=False,
#     run_emchain=False,
#     **kwargs,
# )
# Docstring:
# Function to do all basic analysis tasks. The function will:
#
#     1. Download data by calling 'download_data'
#     2. Call the function 'calibrate_odf'
#         A. Run 'cifbuild'
#         B. Run 'odfingest'
#     2. Run 'epproc' -OR- 'epchain'
#     3. Run 'emproc' -OR- 'emchain'
#     4. Run 'rgsproc'
#
# If 'run_epchain' is set to 'True', then 'epproc' will not run.
# If 'run_emchain' is set to 'True', then 'emproc' will not run.
#
# Inputs:
#
#     data_dir:    Data directory.
#     repo:        Download repository ('esa','heasarc','fornax','aws').
#     overwrite:   Remove previous data files and download again.
#     rerun:       Rerun the *procs or *chains.
#     recalibrate: Rerun 'cifbuild' and 'odfingest'.
#
# All input arguments for 'download_ODF_data' and 'calibrate_odf'
# can be passed to 'basic_setup'.
#
# 'download_ODF_data' inputs (with defaults):
#
#     repo             = 'esa'
#     data_dir         = None
#     overwrite        = False
#     proprietary      = False
#     credentials_file = None
#     encryption_key   = None
#
# 'calibrate_odf' inputs (with defaults):
#
#     obs_dir        = None
#     sas_ccf        = None
#     sas_odf        = None
#     cifbuild_opts  = {}
#     odfingest_opts = {}
#     recalibrate    = False
#
# Input arguments for 'epproc', 'emproc', and 'rgsproc' can also be
# passed in using 'epproc_args', 'emproc_args', or 'rgsproc_args'
# respectively (or 'epchain_args' and 'emchain_args'). By defaut
# 'epproc', 'emproc', and 'rgsproc' will not rerun if output files
# are found, but they can be forced to rerun by setting 'rerun=True'
# as an input to 'basic_setup'.
#
# Examples for use:
#
#     my_obs.basic_setup()
#
#         - Uses the defaults.
#
#     my_obs.basic_setup(repo='heasarc')
#
#         - Uses the defaults, but downloads data from the HEASARC.
#
#     my_obs.basic_setup(overwrite=True)
#
#         - Will erase any previous data files for the Obs ID and
#           download a fresh set of data files.
#
#     my_obs.basic_setup(recalibrate=True)
#
#         - Will rerun cifbuild and odfingest to generate new
#           ccf.cif and *SUM.SAS files.
#
#     my_obs.basic_setup(rerun=True)
#
#         - Will **not** download new files, but will rerun 'epproc',
#           'emproc', and 'rgsproc' and create new event lists.
#
#     my_obs.basic_setup(repo='heasarc',
#                        epproc_args=['withoutoftime=yes'])
#
#         - Downloads data from the HEASARC and runs 'epproc' with the
#           'withoutoftime' option.
#
#     my_obs.basic_setup(run_epchain=True,
#                        run_emchain=True)
#
#         - Will run 'epchain' and 'emchain' instead of 'epproc' and
#           'emproc'.
#
#     my_obs.basic_setup(run_epproc=False,
#                        run_emproc=False)
#
#         - Will not run 'epproc' or 'emproc'. Will only run 'rgsproc'
#           by default.
#
#     my_obs.basic_setup(run_epproc=False,
#                        run_emproc=True,
#                        run_rgsproc=False)
#
#         - Will only run 'emproc', **not** 'epproc' or 'rgsproc'.
#
#     my_obs.basic_setup(repo='heasarc',encryption_key='XXXXXXXXXXXXXXX')
#
#         - Uses the defaults, but downloads *proprietary* data from
#           the HEASARC. Must provide an encryption key, an alpha-numeric
#           string with 30 characters.
#
#     my_obs.basic_setup(proprietary=True)
#
#         - Uses the defaults, but downloads *proprietary* data from
#           the XSA at ESA. Astroquery will ask for user's Cosmos
#           username and password.
# File:      /opt/envs/sas/lib/python3.12/site-packages/pysas/obsid/obsid.py
# Type:      method

# %% [markdown]
# ```{warning}
# Note that this use of '?' is not valid in 'standard' Python, only in Juypyter notebooks and iPython.
# ```
#
# ## 2. Running SAS commands in Python
#
# To run SAS tasks, especially ones not written in Python, you will need to use a wrapper from pySAS (MyTask). SAS tasks should be run from the work directory. The location of the work directory is stored as a variable in `obs.work_dir`.
#
# ### Moving to the working directory

# %%
start_dir = os.getcwd()

# Moving to the work directory
os.chdir(obs.work_dir)

# %% [markdown]
# ### Executing your first pySAS task
#
# The wrapper (which we imported as `w`) takes two inputs, the name of the SAS task to run, and a Python list of all the input arguments for that task. For example, to run a task with no input arguments you simply provide an empty list as the second argument.
#
# The most common SAS tasks to run are: `epproc`, `emproc`, and `rgsproc`. Each one can be run without inputs (but some inputs are needed for more advanced analysis). These tasks have been folded into the function `basic_setup`, but they can be run individually.

# %%
inargs = []
MyTask("emproc", inargs).run()
# Out:
# Executing:
# emproc selectinstruments='no' emos1='no' emos2='no' removetemporaries='yes' removeintermediategtis='yes' removeintermediateeventlists='yes' withinstexpids='no' instexpids='M1S001 M2S001' selectccds='no' ccd1='no' ccd2='no' ccd3='no' ccd4='no' ccd5='no' ccd6='no' ccd7='no' selectmodes='yes' imaging='yes' rimaging='yes' timing='yes' ctiming='no' withgtiset='no' gtiset='gti.ds' runhkgtigen='yes' runatthkgen='yes' referencepointing='median' ra='0' dec='0' posangle='0' filterevents='yes' filterexpression='(FLAG & 0x762aa000) == 0' flagfilteredevents='no' rungtimerge='no' applygti='yes' runevlistcomb='yes' searchforbadpixels='yes' badpixfindalgo='embadpixfind' searchforbadcolumns='yes' withbadpixgti='no' badpixgti='bapixgti.ds' thresholdlabel='rate' lothresh='0' hithresh='0.005' columnsearchlabel='median' locolthresh='0' hicolthresh='0.002' flickertimesteps='1' flickerksthresh='0.55' flickerchisqthresh='15' backgroundrate='-1' narrowerthanpsf='3' threshabovebackground='no' loenergythresh='0' hienergythresh='30' useccfdarkframe='no' randomizeenergy='yes' correctgain='yes' correctcti='yes' ontimepha='no' keepsifluor='no' randomizeposition='yes' rejectrows='yes' maxeventsperrow='4' randomizetime='yes' withsrccoords='no' srcra='0' srcdec='0' withparameters='no' parameters='' except='no' withoverrideparameters='no' overrideparameters='' analyzingSciSimdata='no' findlowener='yes' timebin='52.0'
# emproc:- Executing (routine): emproc selectinstruments=no emos1=no emos2=no removetemporaries=yes removeintermediategtis=yes removeintermediateeventlists=yes withinstexpids=no instexpids='M1S001 M2S001' selectccds=no ccd1=no ccd2=no ccd3=no ccd4=no ccd5=no ccd6=no ccd7=no selectmodes=yes imaging=yes rimaging=yes timing=yes ctiming=no withgtiset=no gtiset=gti.ds runhkgtigen=yes runatthkgen=yes referencepointing=median ra=0 dec=0 posangle=0 filterevents=yes filterexpression='(FLAG & 0x762aa000) == 0' flagfilteredevents=no rungtimerge=no applygti=yes runevlistcomb=yes searchforbadpixels=yes badpixfindalgo=embadpixfind searchforbadcolumns=yes withbadpixgti=no badpixgti=bapixgti.ds thresholdlabel=rate lothresh=0 hithresh=0.005 columnsearchlabel=median locolthresh=0 hicolthresh=0.002 flickertimesteps=1 flickerksthresh=0.55 flickerchisqthresh=15 backgroundrate=-1 narrowerthanpsf=3 threshabovebackground=no loenergythresh=0 hienergythresh=30 useccfdarkframe=no randomizeenergy=yes correctgain=yes correctcti=yes ontimepha=no keepsifluor=no randomizeposition=yes rejectrows=yes maxeventsperrow=4 randomizetime=yes withsrccoords=no srcra=0 srcdec=0 withparameters=no parameters='' except=no withoverrideparameters=no overrideparameters='' analyzingSciSimdata=no findlowener=yes timebin=52  -w 1 -V 4
# emproc:- emproc (epicproc-2.25.4)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:40.000
# emproc:- Processing data for instrument 4 [EMOS1]
# emproc:- Selected data mode: 0 [Imaging]
# emproc:- Selected data mode: 2 [ReducedImaging]
# emproc:- Selected data mode: 1 [Timing]
# emproc:- Selected CCD: 1
# emproc:- Selected CCD: 2
# emproc:- Selected CCD: 3
# emproc:- Selected CCD: 4
# emproc:- Selected CCD: 5
# emproc:- Selected CCD: 6
# emproc:- Selected CCD: 7
# emproc:- 0 [Imaging] -> 1
# emproc:- 2 [ReducedImaging] -> 0
# emproc:- 1 [Timing] -> 0
# emproc:- Considering one of the 1 exposures for mode 0 [Imaging]
# emproc:- Considering exposure M1S001[index=0]
# emproc:- Considering one of the 0 exposures for mode 2 [ReducedImaging]
# emproc:- Considering one of the 0 exposures for mode 1 [Timing]
# emproc:- Selected exposure: 1 mode 0 [Imaging]
# emproc:- .//3278_0802710101_AttHk.ds exists. atthkgen will not be run again.
# emproc:- Executing (invoked): hkgtigen instrument=emos1 gtiset=.//3278_0802710101_EMOS1_HkGti.ds diagfile=STDOUT plotgtis=no diagnosticmode=no withgtiset=yes parameters='' withparameters=no except=no overrideparameters='' overrideparametervalues='' withoverrideparameters=no timecolumn=TIME prefraction=0.5 postfraction=0.5  -w 1 -V 4
# emproc:- hkgtigen (hkgtigen-1.15.1)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:40.000
# emproc::hkgtigen:- Executing (routine): hkgtigen instrument=emos1 gtiset=.//3278_0802710101_EMOS1_HkGti.ds diagfile=STDOUT plotgtis=no diagnosticmode=no withgtiset=yes parameters='' withparameters=no except=no overrideparameters='' overrideparametervalues='' withoverrideparameters=no timecolumn=TIME prefraction=0.5 postfraction=0.5  -w 1 -V 4
# emproc::hkgtigen:- hkgtigen (hkgtigen-1.15.1)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:40.000
# emproc::hkgtigen:- hkgtigen (hkgtigen-1.15.1)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:40.000
# emproc:- hkgtigen (hkgtigen-1.15.1)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:40.000
# emproc:- Processing S001
# emproc:- Processing data set: /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00110IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_01_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_01_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00110IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_01_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:40.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_01_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_01_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00110IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_01_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:40.000
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_01_FramesTemp.ds with        7947  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   625921276.01684570
# emproc::emframes:-  Approximate   end time =   625942730.56415582
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   117.505104      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.969705582
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98870534276862587
# emproc::emframes:-  Writing extension STDGTI01
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_01_FrmGti.ds with           1  rows
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:41.000
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:41.000
# emproc:- Executing (invoked): emevents odfeventset=.//3278_0802710101_EMOS1_S001_01_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_01_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:41.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//3278_0802710101_EMOS1_S001_01_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_01_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:41.000
# emproc::emevents:-        53815  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-        53815  events in output
# emproc::emevents:-          138  events outside good frames
# emproc::emevents:-        22771  cosmic-ray events
# emproc::emevents:-          679  events outside window
# emproc::emevents:-  maximum number of expected events per row  0.11744712990936555
# emproc::emevents:-         1228  events in rows with more than           4  events above expected.
# emproc::emevents:-           27  flagged events next to bad rows
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-         2427  events with E3 <         -29  + local median
# emproc::emevents:-  maximum number of expected events per bin   1.29009068
# emproc::emevents:-           10  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-         4486  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.443705291
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:41.000
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:41.000
# emproc:- Executing (invoked): emenergy ineventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:41.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:41.000
# emproc::emenergy:-  Input file : .//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-        53815  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-         2630  events outside field of view
# emproc::emenergy:-         6915  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-          131  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-         7342  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-         3472  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:42.000
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:42.000
# emproc:- Executing (invoked): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:42.000
# emproc::emeventsproj:- Executing (routine): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:42.000
# emproc::emeventsproj:-  Opening input event file : .//3278_0802710101_EMOS1_S001_01_EvtsForBadpixfindTemp.ds
# emproc::emeventsproj:- The counts will be projected.
# emproc::emeventsproj:- Events flagged for rejection will not be projected.
# emproc::emeventsproj:-  Opening output image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::emeventsproj:-  Number of good events in input file:        21435
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:42.000
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:42.000
# emproc:- Executing (invoked): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_01_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:42.000
# emproc::embadpixfind:- Executing (routine): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_01_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:42.000
# emproc::embadpixfind:-  Opening image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::embadpixfind:-  Half width for 2D searches:           2
# emproc::embadpixfind:-  False detection probability:   9.99999997E-07  per pixel
# emproc::embadpixfind:- The task will also look for bad segments in rows or columns
# emproc::embadpixfind:-  Half width for 1D searches:           3
# emproc::embadpixfind:- The task will look for bright pixels
# emproc::embadpixfind:-  The task will look for bright pixels more than   1.50000000      relative to their neighbours
# emproc::embadpixfind:- The task will look for dark pixels
# emproc::embadpixfind:-  The task will look for dark pixels less than  0.500000000      relative to their neighbours
# emproc::embadpixfind:-  Bad pixels will be written to .//3278_0802710101_EMOS1_S001_01_Badpixels.ds
# emproc::embadpixfind:- Dead pixels from the CAL will be included in the bad pixels list
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           1
# emproc::embadpixfind:-           26  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           5  bright columns found in image
# emproc::embadpixfind:-            0  dark and           3  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           2
# emproc::embadpixfind:-            0  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           0  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-  Writing         983  rows to .//3278_0802710101_EMOS1_S001_01_Badpixels.ds:BADPIX
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:43.000
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:43.000
# emproc:- Processing data set: /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00120IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_02_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_02_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00120IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_02_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:43.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_02_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_02_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00120IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_02_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:43.000
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_02_FramesTemp.ds with        7947  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   625921276.02604353
# emproc::emframes:-  Approximate   end time =   625942730.57331359
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   76.9555511      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.635072231
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98790795354675198
# emproc::emframes:-  Writing extension STDGTI02
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_02_FrmGti.ds with           1  rows
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:44.000
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:44.000
# emproc:- Executing (invoked): emevents odfeventset=.//3278_0802710101_EMOS1_S001_02_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_02_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:44.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//3278_0802710101_EMOS1_S001_02_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_02_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:44.000
# emproc::emevents:-       317042  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       317042  events in output
# emproc::emevents:-          177  events outside good frames
# emproc::emevents:-        20203  cosmic-ray events
# emproc::emevents:-          672  events outside window
# emproc::emevents:-  maximum number of expected events per row   1.0702416918429003
# emproc::emevents:-           79  events in rows with more than           4  events above expected.
# emproc::emevents:-           26  flagged events next to bad rows
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-          273  events with E3 <         -68  + local median
# emproc::emevents:-  maximum number of expected events per bin   3.93258286
# emproc::emevents:-           24  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-         5234  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.916752338
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:47.000
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:47.000
# emproc:- Executing (invoked): emenergy ineventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:47.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:47.000
# emproc::emenergy:-  Input file : .//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-       317042  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-        25167  events outside field of view
# emproc::emenergy:-       205480  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-          454  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-        91560  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-        68409  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:48.000
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:48.000
# emproc:- Executing (invoked): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:48.000
# emproc::emeventsproj:- Executing (routine): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:48.000
# emproc::emeventsproj:-  Opening input event file : .//3278_0802710101_EMOS1_S001_02_EvtsForBadpixfindTemp.ds
# emproc::emeventsproj:- The counts will be projected.
# emproc::emeventsproj:- Events flagged for rejection will not be projected.
# emproc::emeventsproj:-  Opening output image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::emeventsproj:-  Number of good events in input file:       161466
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:49.000
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:49.000
# emproc:- Executing (invoked): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_02_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:49.000
# emproc::embadpixfind:- Executing (routine): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_02_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:49.000
# emproc::embadpixfind:-  Opening image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::embadpixfind:-  Half width for 2D searches:           2
# emproc::embadpixfind:-  False detection probability:   9.99999997E-07  per pixel
# emproc::embadpixfind:- The task will also look for bad segments in rows or columns
# emproc::embadpixfind:-  Half width for 1D searches:           3
# emproc::embadpixfind:- The task will look for bright pixels
# emproc::embadpixfind:-  The task will look for bright pixels more than   1.50000000      relative to their neighbours
# emproc::embadpixfind:- The task will look for dark pixels
# emproc::embadpixfind:-  The task will look for dark pixels less than  0.500000000      relative to their neighbours
# emproc::embadpixfind:-  Bad pixels will be written to .//3278_0802710101_EMOS1_S001_02_Badpixels.ds
# emproc::embadpixfind:- Dead pixels from the CAL will be included in the bad pixels list
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           1
# emproc::embadpixfind:-          606  bright pixels found in image
# emproc::embadpixfind:-            0  dark and          10  bright columns found in image
# emproc::embadpixfind:-            0  dark and           3  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           2
# emproc::embadpixfind:-            0  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           0  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-  Writing         972  rows to .//3278_0802710101_EMOS1_S001_02_Badpixels.ds:BADPIX
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:50.000
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:50.000
# emproc:- Processing data set: /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00140IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_04_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_04_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00140IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_04_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:50.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_04_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_04_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00140IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_04_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:50.000
# emproc::emframes:-            1  extended frames in FRAMES
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_04_FramesTemp.ds with        7946  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   625921276.03520131
# emproc::emframes:-  Approximate   end time =   625942730.58251143
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   77.9599686      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.643361092
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98983115727141746
# emproc::emframes:-  Writing extension STDGTI04
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_04_FrmGti.ds with           1  rows
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:51.000
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:51.000
# emproc:- Executing (invoked): emevents odfeventset=.//3278_0802710101_EMOS1_S001_04_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_04_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:51.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//3278_0802710101_EMOS1_S001_04_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_04_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:51.000
# emproc::emevents:-       181462  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       181462  events in output
# emproc::emevents:-          137  events outside good frames
# emproc::emevents:-        27113  cosmic-ray events
# emproc::emevents:-           76  events outside window
# emproc::emevents:-  maximum number of expected events per row   1.0869948382223342
# emproc::emevents:-           49  events in rows with more than           4  events above expected.
# emproc::emevents:-            7  flagged events next to bad rows
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-         2411  events with E3 <         -45  + local median
# emproc::emevents:-  maximum number of expected events per bin   3.93507242
# emproc::emevents:-           53  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-        13504  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.762203634
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:53.000
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:53.000
# emproc:- Executing (invoked): emenergy ineventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:53.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:53.000
# emproc::emenergy:-  Input file : .//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-       181462  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-        40074  events outside field of view
# emproc::emenergy:-        27049  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-          897  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-        27017  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-        11774  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:54.000
# emproc:- emenergy (emenergy-8.10)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:54.000
# emproc:- Executing (invoked): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:54.000
# emproc::emeventsproj:- Executing (routine): emeventsproj eventset=.//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:54.000
# emproc::emeventsproj:-  Opening input event file : .//3278_0802710101_EMOS1_S001_04_EvtsForBadpixfindTemp.ds
# emproc::emeventsproj:- The counts will be projected.
# emproc::emeventsproj:- Events flagged for rejection will not be projected.
# emproc::emeventsproj:-  Opening output image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::emeventsproj:-  Number of good events in input file:       126380
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:54.000
# emproc:- emeventsproj (emeventsproj-1.6)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:54.000
# emproc:- Executing (invoked): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_04_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:54.000
# emproc::embadpixfind:- Executing (routine): embadpixfind evimageset=.//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//3278_0802710101_EMOS1_S001_04_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:54.000
# emproc::embadpixfind:-  Opening image file : .//3278_0802710101_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::embadpixfind:-  Window limits:           5         600           8         600
# emproc::embadpixfind:-  Half width for 2D searches:           2
# emproc::embadpixfind:-  False detection probability:   9.99999997E-07  per pixel
# emproc::embadpixfind:- The task will also look for bad segments in rows or columns
# emproc::embadpixfind:-  Half width for 1D searches:           3
# emproc::embadpixfind:- The task will look for bright pixels
# emproc::embadpixfind:-  The task will look for bright pixels more than   1.50000000      relative to their neighbours
# emproc::embadpixfind:- The task will look for dark pixels
# emproc::embadpixfind:-  The task will look for dark pixels less than  0.500000000      relative to their neighbours
# emproc::embadpixfind:-  Bad pixels will be written to .//3278_0802710101_EMOS1_S001_04_Badpixels.ds
# emproc::embadpixfind:- Dead pixels from the CAL will be included in the bad pixels list
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           1
# emproc::embadpixfind:-           22  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           5  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           2
# emproc::embadpixfind:-            4  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           0  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-  Writing          53  rows to .//3278_0802710101_EMOS1_S001_04_Badpixels.ds:BADPIX
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:55.000
# emproc:- embadpixfind (embadpixfind-2.8)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:55.000
# emproc:- Processing data set: /home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00150IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_05_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_05_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00150IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_05_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:55.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00100AUX.FIT frameset=.//3278_0802710101_EMOS1_S001_05_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//3278_0802710101_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//3278_0802710101_EMOS1_S001_05_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/ODF/3278_0802710101_M1S00150IME.FIT outeventset=.//3278_0802710101_EMOS1_S001_05_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:55.000
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_05_FramesTemp.ds with        7947  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   625921276.02600348
# emproc::emframes:-  Approximate   end time =   625942730.57331359
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   78.5678635      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.648377776
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98787530670520662
# emproc::emframes:-  Writing extension STDGTI05
# emproc::emframes:-  Create .//3278_0802710101_EMOS1_S001_05_FrmGti.ds with           1  rows
# emproc::emframes:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:56.000
# emproc:- emframes (emframes-5.11)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:24:56.000
# emproc:- Executing (invoked): emevents odfeventset=.//3278_0802710101_EMOS1_S001_05_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_05_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_05_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:56.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//3278_0802710101_EMOS1_S001_05_EvtsFramesTemp.ds eventset=.//3278_0802710101_EMOS1_S001_05_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//3278_0802710101_EMOS1_S001_05_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.9.2)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:24:56.000
# emproc::emevents:-       122217  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       122217  events in output
# emproc::emevents:-           70  events outside good frames
# emproc::emevents:-        22262  cosmic-ray events
# emproc::emevents:-         2761  events outside window
# ...
# emproc:- Executing (invoked): evselect table=.//3278_0802710101_EMOS2_S002_07_Evts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::evselect:- Executing (routine): evselect table=.//3278_0802710101_EMOS2_S002_07_Evts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# ** emproc::evselect: warning (NoCCDcolumn), Event list does not have a CCDNR column. Cannot update exposure information.
# emproc::evselect:- selected 13896 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- Executing (invoked): evlistcomb eventsets='.//3278_0802710101_EMOS2_S002_01_Evts.ds .//3278_0802710101_EMOS2_S002_02_Evts.ds .//3278_0802710101_EMOS2_S002_03_Evts.ds .//3278_0802710101_EMOS2_S002_04_Evts.ds .//3278_0802710101_EMOS2_S002_05_Evts.ds .//3278_0802710101_EMOS2_S002_06_Evts.ds .//3278_0802710101_EMOS2_S002_07_Evts.ds' imagingset=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds timingset=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds maintable='EVENTS OFFSETS' othertables='EXPOSURE BADPIX STDGTI' primarychecks='TELESCOP INSTRUME OBS_ID EXP_ID' primaryonly=ORIGIN extensionchecks='DET_SYST TIMEUNIT TIMESYS MJDREF TIMEREF TASSIGN TIMEZERO CLOCKAPP TCRPX TCTYP TCRVL TCDLT TCROT TCUNI' maxattributes='TSTOP TLMAX TDMAX' minattributes='TSTART TLMIN TDMIN' mainattributes='' emosdatamodes='IMAGING TIMING' emosimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN OFFSETX OFFSETY' emosimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int16' emostimcolnames='TIME RAWX PHA PI FLAG PATTERN OFFSETX' emostimcoltypes='double int16 int16 int16 int32 int8 int16' epndatamodes='IMAGING TIMING' epnimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN PAT_ID PAT_SEQ OFFSETX' epnimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int8 int16' epntimcolnames='TIME RAWX PHA PI FLAG PATTERN' epntimcoltypes='double int16 int16 int16 int32 int8' rgsdatamodes='SPECTROSCOPY HIGHTIMERESOLUTION' rgsimgcolnames='BETA_CORR XDSP_CORR TIME FLAG BETA XDSP CHIPX CHIPY PHA SHAPE GRADE BETA_CHANNEL XDSP_CHANNEL PI' rgsimgcoltypes='single single double int32 single single int16 int16 int16 int8 int8 int16 int16 int16' rgstimcolnames='BETA_CORR TIME FLAG BETA CHIPX PHA BETA_CHANNEL PI' rgstimcoltypes='single double int32 single int16 int16 int16 int16' instrument=emos  -w 1 -V 4
# emproc:- evlistcomb (evlistcomb-4.20)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::evlistcomb:- Executing (routine): evlistcomb eventsets='.//3278_0802710101_EMOS2_S002_01_Evts.ds .//3278_0802710101_EMOS2_S002_02_Evts.ds .//3278_0802710101_EMOS2_S002_03_Evts.ds .//3278_0802710101_EMOS2_S002_04_Evts.ds .//3278_0802710101_EMOS2_S002_05_Evts.ds .//3278_0802710101_EMOS2_S002_06_Evts.ds .//3278_0802710101_EMOS2_S002_07_Evts.ds' imagingset=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds timingset=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds maintable='EVENTS OFFSETS' othertables='EXPOSURE BADPIX STDGTI' primarychecks='TELESCOP INSTRUME OBS_ID EXP_ID' primaryonly=ORIGIN extensionchecks='DET_SYST TIMEUNIT TIMESYS MJDREF TIMEREF TASSIGN TIMEZERO CLOCKAPP TCRPX TCTYP TCRVL TCDLT TCROT TCUNI' maxattributes='TSTOP TLMAX TDMAX' minattributes='TSTART TLMIN TDMIN' mainattributes='' emosdatamodes='IMAGING TIMING' emosimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN OFFSETX OFFSETY' emosimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int16' emostimcolnames='TIME RAWX PHA PI FLAG PATTERN OFFSETX' emostimcoltypes='double int16 int16 int16 int32 int8 int16' epndatamodes='IMAGING TIMING' epnimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN PAT_ID PAT_SEQ OFFSETX' epnimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int8 int16' epntimcolnames='TIME RAWX PHA PI FLAG PATTERN' epntimcoltypes='double int16 int16 int16 int32 int8' rgsdatamodes='SPECTROSCOPY HIGHTIMERESOLUTION' rgsimgcolnames='BETA_CORR XDSP_CORR TIME FLAG BETA XDSP CHIPX CHIPY PHA SHAPE GRADE BETA_CHANNEL XDSP_CHANNEL PI' rgsimgcoltypes='single single double int32 single single int16 int16 int16 int8 int8 int16 int16 int16' rgstimcolnames='BETA_CORR TIME FLAG BETA CHIPX PHA BETA_CHANNEL PI' rgstimcoltypes='single double int32 single int16 int16 int16 int16' instrument=emos  -w 1 -V 4
# emproc::evlistcomb:- evlistcomb (evlistcomb-4.20)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::evlistcomb:-  Instrument name : emos
# emproc::evlistcomb:-            2  input names for parameter :emosdatamodes
# emproc::evlistcomb:-           13  input names for parameter :emosimgcolnames
# emproc::evlistcomb:-           13  input names for parameter :emosimgcoltypes
# emproc::evlistcomb:-            7  input names for parameter :emostimcolnames
# emproc::evlistcomb:-            7  input names for parameter :emostimcoltypes
# emproc::evlistcomb:-            2  input names for parameter :maintable
# emproc::evlistcomb:-  Main table name : EVENTS
# emproc::evlistcomb:-            0  input names for parameter :mainattributes
# emproc::evlistcomb:-            3  input names for parameter :minattributes
# emproc::evlistcomb:-            3  input names for parameter :maxattributes
# emproc::evlistcomb:-            3  input names for parameter :othertables
# emproc::evlistcomb:-            4  input names for parameter :primarychecks
# emproc::evlistcomb:-            1  input names for parameter :primaryonly
# emproc::evlistcomb:-           14  input names for parameter :extensionchecks
# emproc::evlistcomb:-            7  input event files
# emproc::evlistcomb:-  Entering mode IMAGING
# emproc::evlistcomb:-  Create .//3278_0802710101_EMOS2_S002_ImagingEvts.ds
# emproc::evlistcomb:-  .//3278_0802710101_EMOS2_S002_ImagingEvts.ds:EVENTS has      104011  rows
# emproc::evlistcomb:-  .//3278_0802710101_EMOS2_S002_ImagingEvts.ds:OFFSETS has          56  rows
# emproc::evlistcomb:-  Writing extension EXPOSU01 from .//3278_0802710101_EMOS2_S002_01_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX01 from .//3278_0802710101_EMOS2_S002_01_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_01_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU02 from .//3278_0802710101_EMOS2_S002_02_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX02 from .//3278_0802710101_EMOS2_S002_02_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_02_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU03 from .//3278_0802710101_EMOS2_S002_03_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX03 from .//3278_0802710101_EMOS2_S002_03_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_03_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU04 from .//3278_0802710101_EMOS2_S002_04_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX04 from .//3278_0802710101_EMOS2_S002_04_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_04_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU05 from .//3278_0802710101_EMOS2_S002_05_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX05 from .//3278_0802710101_EMOS2_S002_05_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_05_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU06 from .//3278_0802710101_EMOS2_S002_06_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX06 from .//3278_0802710101_EMOS2_S002_06_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_06_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU07 from .//3278_0802710101_EMOS2_S002_07_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX07 from .//3278_0802710101_EMOS2_S002_07_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//3278_0802710101_EMOS2_S002_07_Evts.ds
# emproc::evlistcomb:-  Entering mode TIMING
# emproc::evlistcomb:-  No output for mode TIMING
# emproc::evlistcomb:- evlistcomb (evlistcomb-4.20)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- evlistcomb (evlistcomb-4.20)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- Executing (invoked): dscopyblock blocks=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/ccf.cif:CALINDEX to=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds  -w 1 -V 4
# emproc:- dscopyblock (daltools-1.11.1)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::dscopyblock:- Executing (routine): dscopyblock blocks=/home/jovyan/projects/heasarc-tutorials/_data/XMM/0802710101/work/ccf.cif:CALINDEX to=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds  -w 1 -V 4
# emproc::dscopyblock:- dscopyblock (daltools-1.11.1)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::dscopyblock:- dscopyblock (daltools-1.11.1)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- dscopyblock (daltools-1.11.1)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:03.000
# emproc:- Executing (invoked): evselect table=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(( CCDNR == 1 && TIME in gti(.//3278_0802710101_EMOS2_S002_01_FrmGti.ds:STDGTI01))||( CCDNR == 2 && TIME in gti(.//3278_0802710101_EMOS2_S002_02_FrmGti.ds:STDGTI02))||( CCDNR == 3 && TIME in gti(.//3278_0802710101_EMOS2_S002_03_FrmGti.ds:STDGTI03))||( CCDNR == 4 && TIME in gti(.//3278_0802710101_EMOS2_S002_04_FrmGti.ds:STDGTI04))||( CCDNR == 5 && TIME in gti(.//3278_0802710101_EMOS2_S002_05_FrmGti.ds:STDGTI05))||( CCDNR == 6 && TIME in gti(.//3278_0802710101_EMOS2_S002_06_FrmGti.ds:STDGTI06))||( CCDNR == 7 && TIME in gti(.//3278_0802710101_EMOS2_S002_07_FrmGti.ds:STDGTI07)))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::evselect:- Executing (routine): evselect table=.//3278_0802710101_EMOS2_S002_ImagingEvts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(( CCDNR == 1 && TIME in gti(.//3278_0802710101_EMOS2_S002_01_FrmGti.ds:STDGTI01))||( CCDNR == 2 && TIME in gti(.//3278_0802710101_EMOS2_S002_02_FrmGti.ds:STDGTI02))||( CCDNR == 3 && TIME in gti(.//3278_0802710101_EMOS2_S002_03_FrmGti.ds:STDGTI03))||( CCDNR == 4 && TIME in gti(.//3278_0802710101_EMOS2_S002_04_FrmGti.ds:STDGTI04))||( CCDNR == 5 && TIME in gti(.//3278_0802710101_EMOS2_S002_05_FrmGti.ds:STDGTI05))||( CCDNR == 6 && TIME in gti(.//3278_0802710101_EMOS2_S002_06_FrmGti.ds:STDGTI06))||( CCDNR == 7 && TIME in gti(.//3278_0802710101_EMOS2_S002_07_FrmGti.ds:STDGTI07)))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:03.000
# emproc::evselect:- selected 104011 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:04.000
# emproc:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:04.000
# emproc:- emproc (epicproc-2.25.4)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:04.000
# emproc executed successfully!

# %% [markdown]
# ### Listing input arguments for pySAS tasks
#
# You can list all input arguments available to any SAS task with option `'--help'` (or `'-h'`).

# %%
MyTask("emproc", ["-h"]).run()
# Out:
#         Usage: emproc [Options] param0=value0 [param1=value1] ...
#
#         Options:
#         -a | --ccfpath <dir1>:<dir2>...   Sets SAS_CCFPATH to <dir1>:<dir2>...
#         -c | --noclobber                  Set SAS_CLOBBER=0
#         -d | --dialog                     Launchs task GUI
#         -f | --ccffiles <f1> <f2> ...     CCF files
#         -h | --help                       Shows this message, display param file contents and exits
#         -i | --ccf <cif>                  Sets SAS_CCF=<cif> (ccf.cif)
#         -m | --manpage                    Opens web browser with task documentation
#         -o | --odf <sumfile>              Sets SAS_ODF to SAS summary file
#         -p | --param                      List of all available task parameters with default values
#         -t | --trace                      Trace task execution
#         -V | --verbosity <level>          Sets verbosity level and sets SAS_VERBOSITY
#         -v | --version                    Shows task name and version, and exits
#         -w | --warning [code|n]           Set warning code to [code|n]
#
#         Parameters:
#         param0=value0                     A mandatory parameter. If not present, exits.
#         [param1=value1]                   An optional parameter. If not present, it might have a default value
#         ...
#
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       name                       |   mandatory   |   type   |           default            |                   description                    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                selectinstruments                 |      no       |   bool   |              no              | Select one of the cameras? false = process both  |
# |                                                  |               |          |                              |                   instruments.                   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      emos1                       |      no       |   bool   |              no              |                Process EMOS1 data                |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      emos2                       |      no       |   bool   |              no              |                Process EMOS2 data                |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                removetemporaries                 |      no       |   bool   |             yes              |           Remove temporary data sets?            |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |              removeintermediategtis              |      no       |   bool   |             yes              |        Remove intermediate GTI data sets?        |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |           removeintermediateeventlists           |      no       |   bool   |             yes              | Remove the intermediate CCD/node-based event lis |
# |                                                  |               |          |                              |                       ts?                        |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  withinstexpids                  |      no       |   bool   |              no              |           Select exposures to process?           |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    instexpids                    |      no       |  string  |       "M1S001 M2S001"        |          List of exposures to process.           |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    selectccds                    |      no       |   bool   |              no              | Select the CCDs to process? false = process all  |
# |                                                  |               |          |                              |                      CCDs.                       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd1                       |      no       |   bool   |              no              |             Process data for CCD 1?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd2                       |      no       |   bool   |              no              |             Process data for CCD 2?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd3                       |      no       |   bool   |              no              |             Process data for CCD 3?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd4                       |      no       |   bool   |              no              |             Process data for CCD 4?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd5                       |      no       |   bool   |              no              |             Process data for CCD 5?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd6                       |      no       |   bool   |              no              |             Process data for CCD 6?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       ccd7                       |      no       |   bool   |              no              |             Process data for CCD 7?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   selectmodes                    |      no       |   bool   |             yes              | Select the modes to process? false = process all |
# |                                                  |               |          |                              |                      modes.                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     imaging                      |      no       |   bool   |             yes              |          Process imaging mode exposure?          |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     rimaging                     |      no       |   bool   |             yes              |      Process reduced imaging mode exposure?      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      timing                      |      no       |   bool   |             yes              |          Process timing mode exposures?          |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     ctiming                      |      no       |   bool   |              no              |    Process compressed timing mode exposures?     |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    withgtiset                    |      no       |   bool   |              no              | Use an external GTI dataset to be used when filt |
# |                                                  |               |          |                              |                 ering the data?                  |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      gtiset                      |      no       | dataset  |            gti.ds            | Name of the external GTI dataset to be used when |
# |                                                  |               |          |                              |                filtering the data.               |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   runhkgtigen                    |      no       |   bool   |             yes              |  Generate a GTI dataset based on housekeeping?   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   runatthkgen                    |      no       |   bool   |             yes              |   Pre-process attitude data through atthkgen?    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                referencepointing                 |      no       |  string  |            median            | Coordinates of the reference poiting used for th |
# |                                                  |               |          |                              |       e calculation of the sky coordinates       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                        ra                        |      no       |  angle   |              0               | User-specified right ascension of s/c attitude ( |
# |                                                  |               |          |                              |                       deg)                       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       dec                        |      no       |  angle   |              0               | User-specified declination of s/c attitude (deg) |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     posangle                     |      no       |  angle   |              0               | User-specified astronomical position angle of s/ |
# |                                                  |               |          |                              |                 c attitude (deg)                 |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   filterevents                   |      no       |   bool   |             yes              |             Filter the event lists?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 filterexpression                 |      no       |  string  |   (FLAG & 0x762aa000) == 0   |         Bad events selection expression.         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                flagfilteredevents                |      no       |   bool   |              no              | Flag the events that match the filter expression |
# |                                                  |               |          |                              |             instead of removing them?            |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   rungtimerge                    |      no       |   bool   |              no              |           Merge all GTIs from each CCD           |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     applygti                     |      no       |   bool   |             yes              |       Apply GTI filter to the event lists?       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  runevlistcomb                   |      no       |   bool   |             yes              | Merge CCD-level event lists into exposure-level  |
# |                                                  |               |          |                              |              event lists (by mode)?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                searchforbadpixels                |      no       |   bool   |             yes              |              Search for bad pixels?              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  badpixfindalgo                  |      no       |  string  |         embadpixfind         |           Specify the badpix algorithm           |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |               searchforbadcolumns                |      no       |   bool   |             yes              |              Look for bad columns?               |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  withbadpixgti                   |      no       |   bool   |              no              | Search for bad pixels only in the given good tim |
# |                                                  |               |          |                              |                   e intervals?                   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    badpixgti                     |      no       | dataset  |         bapixgti.ds          | Good time intervals to use while searching for b |
# |                                                  |               |          |                              |                    ad pixels.                    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  thresholdlabel                  |      no       |  string  |             rate             | Thresholds choice - as percentage of PEAK, as co |
# |                                                  |               |          |                              |      unt RATE or pure COUNTS [!badpixfind]       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     lothresh                     |      no       |   real   |              0               | Low threshold to search for dead pixels  [badpix |
# |                                                  |               |          |                              |                      find]                       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     hithresh                     |      no       |   real   |            0.005             | High threshold to search for hot pixels  [!badpi |
# |                                                  |               |          |                              |                      xfind]                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                columnsearchlabel                 |      no       |  string  |            median            | Columnsearch thresholds choice - refer to TOTAL  |
# |                                                  |               |          |                              | column value or MEDIAN column value [badpixfind] |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   locolthresh                    |      no       |   real   |              0               | Low threshold to search for dead columns  [badpi |
# |                                                  |               |          |                              |                      xfind]                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   hicolthresh                    |      no       |   real   |            0.002             | High threshold to search for hot columns  [badpi |
# |                                                  |               |          |                              |                      xfind]                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 flickertimesteps                 |      no       |   int    |              1               | Number of timesteps to search for flickering pix |
# |                                                  |               |          |                              |                els  [badpixfind]                 |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 flickerksthresh                  |      no       |   real   |             0.55             | K-S threshold for low count flickering pixels  [ |
# |                                                  |               |          |                              |                   badpixfind]                    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                flickerchisqthresh                |      no       |   real   |              15              | Reduced Chi-sq threshold for high count flickeri |
# |                                                  |               |          |                              |             ng pixels  [badpixfind]              |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  backgroundrate                  |      no       |   real   |              -1              | Background rate (ct/s/pix) - if negative, mean o |
# |                                                  |               |          |                              |     ver entire field assumed  [!badpixfind]      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 narrowerthanpsf                  |      no       |   real   |              3               | PSF-pixel(s) comparison - 1:equal to PSF, >1:mor |
# |                                                  |               |          |                              |             e compact  [!badpixfind]             |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |              threshabovebackground               |      no       |   bool   |              no              | High thresholds as values above background  [bad |
# |                                                  |               |          |                              |                     pixfind]                     |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  loenergythresh                  |      no       |   real   |              0               | Low energy threshold for searching (keV)  [badpi |
# |                                                  |               |          |                              |                      xfind]                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  hienergythresh                  |      no       |   real   |              30              | Hi energy threshold for searching (keV)  [badpix |
# |                                                  |               |          |                              |                      find]                       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 useccfdarkframe                  |      no       |   bool   |              no              |         Use dark frame in CCF [emenergy]         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 randomizeenergy                  |      no       |   bool   |             yes              |   Randomize PHA within one ADU bin [emenergy]    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   correctgain                    |      no       |   bool   |             yes              |          Use ENERGY sub_task [emenergy]          |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    correctcti                    |      no       |   bool   |             yes              |         Use CTI_CORR sub_task [emenergy]         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    ontimepha                     |      no       |   bool   |              no              |       Use MOS timing correction [emenergy]       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   keepsifluor                    |      no       |   bool   |              no              | Keep as one event diagonals with Si fluorescence |
# |                                                  |               |          |                              |                    [emevents]                    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                randomizeposition                 |      no       |   bool   |             yes              | Randomize DETX/DETY within one pixel [emevents]  |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    rejectrows                    |      no       |   bool   |             yes              | Throw away rows/frames with too many events [eme |
# |                                                  |               |          |                              |                      vents]                      |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                 maxeventsperrow                  |      no       |   int    |              4               | Maximum number of events per row/frame [emevents |
# |                                                  |               |          |                              |                        ]                         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  randomizetime                   |      no       |   bool   |             yes              |   Randomize TIME within one frame [!emevents]    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  withsrccoords                   |      no       |   bool   |              no              | Provide source coordinates (Timing only) [emfram |
# |                                                  |               |          |                              |                       es]                        |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      srcra                       |      no       |  angle   |              0               |    Source right ascension (J2000) [emframes]     |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      srcdec                      |      no       |  angle   |              0               |      Source declination (J2000) [emframes]       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  withparameters                  |      no       |   bool   |              no              | Specify explicit list of HK parameters? [hkgtige |
# |                                                  |               |          |                              |                        n]                        |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                    parameters                    |      no       |  string  |                              |   List of HK parameters to consider [hkgtigen]   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      except                      |      no       |   bool   |              no              | Consider all parameters except those specified [ |
# |                                                  |               |          |                              |                    hkgtigen]                     |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |              withoverrideparameters              |      no       |   bool   |              no              | Specify list of additional parameters? [hkgtigen |
# |                                                  |               |          |                              |                        ]                         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                overrideparameters                |      no       |  string  |                              | List of override/additional parameters [hkgtigen |
# |                                                  |               |          |                              |                        ]                         |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |               analyzingSciSimdata                |      no       |   bool   |              no              | Different options that need to be set up, if we  |
# |                                                  |               |          |                              |            are analyzing SciSim data.            |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                   findlowener                    |      no       |   bool   |             yes              |  Additional run of embadpixfind below 500 eV ?   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     timebin                      |      no       |   real   |             52.0             | Time binning to build histogram for flare reject |
# |                                                  |               |          |                              |                       ion                        |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# True

# %% [markdown]
# ### Tasks with multiple input arguments
#
# If there are multiple input arguments, then each needs to be a separate string in the Python list. For example, here is how to apply a "standard" filter. Our next pySAS call is equivalent to running the following 'standard' SAS command:
#
# ```
# evselect table=unfiltered_event_list.fits withfilteredset=yes \
#     expression='(PATTERN $<=$ 12)&&(PI in [200:12000])&&#XMMEA_EM' \
#     filteredset=filtered_event_list.fits filtertype=expression keepfilteroutput=yes \
#     updateexposure=yes filterexposure=yes
# ```
#
# The input arguments should be in a list, with each input argument a separate string. Note: Some inputs require single quotes to be preserved in the string. This can be done using double quotes to form the string. i.e. `"expression='(PATTERN <= 12)&&(PI in [200:4000])&&#XMMEA_EM'"`

# %%
unfiltered_event_list = "3278_0802710101_EMOS1_S001_ImagingEvts.ds"

inargs = [
    "table={0}".format(unfiltered_event_list),
    "withfilteredset=yes",
    "expression='(PATTERN <= 12)&&(PI in [200:4000])&&#XMMEA_EM'",
    "filteredset=filtered_event_list.fits",
    "filtertype=expression",
    "keepfilteroutput=yes",
    "updateexposure=yes",
    "filterexposure=yes",
]

MyTask("evselect", inargs).run()
# Out:
# Executing:
# evselect table='3278_0802710101_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='yes' withfilteredset='yes' filteredset='filtered_event_list.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(PATTERN <= 12)&&(PI in [200:4000])&&#XMMEA_EM' writedss='no' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PHA' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=3278_0802710101_EMOS1_S001_ImagingEvts.ds filteredset=filtered_event_list.fits withfilteredset=yes keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(PATTERN <= 12)&&(PI in [200:4000])&&#XMMEA_EM' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=no blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] started:  2026-01-09T18:28:04.000
# evselect:- selected 25199 rows from the input table.
# ** evselect: warning (ExpNoDss), Exposure update requested without writing of the data subspace. Exposure information is likely to be incorrect.
# evselect:- evselect (evselect-3.71.3)  [22.1.0-a8f2c2afa-20250304] ended:    2026-01-09T18:28:04.000
# evselect executed successfully!

# %% [markdown]
# ## About this notebook
#
# Author: Ryan Tanner, XMM GOF Scientist
#
# Author: David J Turner, HEASARC Staff Scientist
#
# Updated On: 2025-10-16

# %% [markdown]
# ### Additional Resources
#
# Support: [XMM Newton GOF Helpdesk](https://heasarc.gsfc.nasa.gov/docs/xmm/xmm_helpdesk.html)
#
# ### Acknowledgements
#
# ### References
